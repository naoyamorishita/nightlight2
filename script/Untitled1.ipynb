# %%
import geopandas as gpd
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.10.3-CAPI-1.16.1) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %%
# Read File====
# Download from https://github.com/microsoft/USBuildingFootprints
bld = gpd.read_file("/Volumes/volume 1/GIS Projects/nightlight/phoenix/building_footprint/Arizona.geojson")

# %%
boundary = gpd.read_file("/Users/naoyamorishita/Documents/working/nightlight/data/grid.geojson")
boundary = boundary.to_crs(bld.crs)

# %%
bld.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
boundary.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
bld_phoenix = bld.clip(boundary)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/geopandas/tools/clip.py:67: FutureWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   clipped.loc[

# %%
bld_phoenix
# Out:
#          release  capture_dates_range  \
# 511030         2   5/7/2020-5/21/2020
# 334186         2   5/7/2020-5/21/2020
# 2534307        2   5/7/2020-5/21/2020
# 841791         2   5/7/2020-5/21/2020
# 1829169        2   5/7/2020-5/21/2020
# ...          ...                  ...
# 366986         2  5/22/2020-5/27/2020
# 1442930        2  5/22/2020-5/27/2020
# 73943          2  5/22/2020-5/27/2020
# 1255043        2  5/22/2020-5/27/2020
# 720305         2  5/22/2020-5/27/2020
#
#                                                   geometry
# 511030   POLYGON ((-111.94548 33.44751, -111.94572 33.4...
# 334186   POLYGON ((-111.94431 33.44760, -111.94440 33.4...
# 2534307  POLYGON ((-111.94640 33.44758, -111.94640 33.4...
# 841791   POLYGON ((-111.94901 33.44710, -111.94914 33.4...
# 1829169  POLYGON ((-111.94870 33.44740, -111.94856 33.4...
# ...                                                    ...
# 366986   POLYGON ((-112.19049 33.73869, -112.19055 33.7...
# ...

# %%
ph = gpd.read_file("/Users/naoyamorishita/Documents/working/nightlight/data/ph_phoenix.geojson")

# %%
bld_phoenix = bld_phoenix.to_crs(26949)

# %%
bld_phoenix.crs
# Out:
# <Derived Projected CRS: EPSG:26949>
# Name: NAD83 / Arizona Central
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: United States (USA) - Arizona - counties Coconino; Maricopa; Pima; Pinal; Santa Cruz; Yavapai.
# - bounds: (-113.35, 31.33, -110.44, 37.01)
# Coordinate Operation:
# - name: SPCS83 Arizona Central zone (meters)
# - method: Transverse Mercator
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
bld_phoenix["sqm"] = bld_phoenix.area
bld_phoenix
# Out:
#          release  capture_dates_range  \
# 511030         2   5/7/2020-5/21/2020
# 334186         2   5/7/2020-5/21/2020
# 2534307        2   5/7/2020-5/21/2020
# 841791         2   5/7/2020-5/21/2020
# 1829169        2   5/7/2020-5/21/2020
# ...          ...                  ...
# 366986         2  5/22/2020-5/27/2020
# 1442930        2  5/22/2020-5/27/2020
# 73943          2  5/22/2020-5/27/2020
# 1255043        2  5/22/2020-5/27/2020
# 720305         2  5/22/2020-5/27/2020
#
#                                                   geometry          sqm
# 511030   POLYGON ((210681.152 271379.479, 210658.932 27...   258.203747
# 334186   POLYGON ((210790.393 271389.652, 210781.933 27...   107.021999
# 2534307  POLYGON ((210596.087 271387.488, 210595.628 27...   410.565401
# 841791   POLYGON ((210352.770 271334.549, 210340.963 27...  1275.012563
# 1829169  POLYGON ((210381.973 271367.034, 210394.621 27...   228.999877
# ...

# %%
ph = ph.to_crs(26949)
ph.crs
# Out:
# <Derived Projected CRS: EPSG:26949>
# Name: NAD83 / Arizona Central
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: United States (USA) - Arizona - counties Coconino; Maricopa; Pima; Pinal; Santa Cruz; Yavapai.
# - bounds: (-113.35, 31.33, -110.44, 37.01)
# Coordinate Operation:
# - name: SPCS83 Arizona Central zone (meters)
# - method: Transverse Mercator
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
phbld = ph.sjoin_nearest(bld_phoenix)

# %%
phbld
plot
# Out:
#      OBJECTID  TOTAL_OCCUPIED  OBJECTID.1             NAME  \
# 0         259               0        2563  City of Phoenix
# 1         315               2        2563  City of Phoenix
# 75      24835               0        2563  City of Phoenix
# 136     46081               0        2563  City of Phoenix
# 2         317               1        2563  City of Phoenix
# ..        ...             ...         ...              ...
# 570    194093               1        2563  City of Phoenix
# 572    194329               1        2563  City of Phoenix
# 574    194941               1        2563  City of Phoenix
# 575    195104               0        2563  City of Phoenix
# 576    196394               1        2563  City of Phoenix
#
#                           geometry  index_right  release  capture_dates_range  \
# 0    POINT (197305.535 270371.480)      2562307        2   5/7/2020-5/21/2020
# 1    POINT (197653.497 270448.429)      2315012        2   5/7/2020-5/21/2020
# ...

# %%
phbld.to_file("/Users/naoyamorishita/Documents/working/nightlight/data/bldph_new.geojson")
